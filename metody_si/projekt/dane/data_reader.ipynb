# %%
import pandas as pd


file = pd.read_csv("merged_data.csv", encoding="utf-8")
print(file.head())
print("="*70)
print(file.info())
print("="*70)
print(file.describe())
# Out:
#          NSP      POST   ROK  MC  DZ  TMAX  WTMAX  TMIN  WTMIN  STD  WSTD  \
# 0  249180010  PSZCZYNA  2001   1   1  -1.3    NaN  -9.6    NaN -5.7   NaN
# 1  249180010  PSZCZYNA  2001   1   2   3.3    NaN -12.0    NaN -2.7   NaN
# 2  249180010  PSZCZYNA  2001   1   3   1.5    NaN  -5.7    NaN -1.5   NaN
# 3  249180010  PSZCZYNA  2001   1   4   6.5    NaN  -1.1    NaN  1.9   NaN
# 4  249180010  PSZCZYNA  2001   1   5   6.5    NaN  -2.3    NaN  2.8   NaN
#
#    TMNG  WTMNG  SMDB  WSMDB ROOP  PKSN  WPKSN
# 0 -11.0    NaN   0.0    9.0  NaN  13.0    NaN
# 1 -13.2    NaN   0.0    9.0  NaN  11.0    NaN
# 2  -6.8    NaN   0.0    9.0  NaN  10.0    NaN
# 3  -4.8    NaN   0.0    9.0  NaN   8.0    NaN
# 4  -6.5    NaN   0.3    NaN    W   7.0    NaN
# ...
# <class 'pandas.DataFrame'>
# RangeIndex: 1062629 entries, 0 to 1062628
# Data columns (total 18 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   NSP     1062629 non-null  int64
# ...
