# %%
import pandas as pd

df = pd.read_csv('zadanie_3_brak.csv')

df = df.head(500)

df = df[['Date', 'Open', 'Close', 'Volume']]

df = df.dropna(subset=['Open'])

print(df.head(10))
# Out:
#          Date        Open       Close     Volume
# 0  2022-06-01  509.256750  242.193371  1319529.0
# 1  2022-06-02  407.184211  434.235074   965875.0
# 2  2022-06-03  339.238237  417.737955  1874883.0
# 3  2022-06-04  348.695718  293.496317  1818985.0
# 4  2022-06-05  200.541450  455.109657   276609.0
# 5  2022-06-06  319.920211  528.027001  1775031.0
# 6  2022-06-07  458.583497  216.631584  1389564.0
# 7  2022-06-08  589.677778  399.251977   201322.0
# 8  2022-06-09  538.824331  475.724165  1926897.0
# 9  2022-06-10  209.437986  300.924771  1593114.0
